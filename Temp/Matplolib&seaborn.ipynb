# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5,6]
y = [65,2,90,100,111,30]

plt.plot(x,y , ls = 'dotted', marker = 'o', lw = 2 , animated = True , c = 'y' , label = 'Practice Graph')
plt.grid(True , c = 'b' , ls = ':' , lw = 1)
plt.title('Practice Graph')
plt.xlabel('x-Head')
plt.ylabel('y-Head')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


file = pd.read_csv('BUSinT.csv')


file['classes'] = file['roll_no'].str.split('/').str[1]





def grades(score):
    if score >= 80:
        return "A"
    elif score >= 70:
        return "B"
    elif score >= 60:
        return "C"
    elif score >= 50:
        return "D"
    else:
        return "F"

file['grades'] = students["perc"].apply(grades)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 27
#      24     else:
#      25         return "F"
# ---> 27 file['grades'] = students["perc"].apply(grades)
#
# NameError: name 'students' is not defined

# %%
x = ['1st Term','2nd Term','Final Term']
plt.bar(x,)
plt.title('created by: M.Muneeb')
plt.xlabel('Classes')
plt.ylabel('Marks')

plt.grid(ls = '')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 x = ['1st Term','2nd Term','Final Term']
# ----> 2 plt.bar(x,)
#       3 plt.title('created by: M.Muneeb')
#       4 plt.xlabel('Classes')
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
x = [1,2,3,4,5,6,7]
y = [23,65,21,54,90,54,23]

# %%
plt.subplot(2,2,3)
plt.bar(x,y)
plt.xticks([1,2,3,4,5,6,7])
plt.subplot(2,2,4)
plt.plot(x,y)
plt.xticks([1,2,3,4,5,6,7])
plt.show()

# %%
import seaborn as sns

tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'total_bill',y = 'tip', data = tips, hue = 'smoker' , col = 'time', row = 'size')

# %%
sns.barplot(x = 'smoker',y = 'tip', data = tips, hue = 'sex')
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
flight.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 flight.head()
#
# NameError: name 'flight' is not defined

# %%
import seaborn as sns
flight = sns.load_dataset('flights')
sns.lineplot(y = 'passengers' , x = 'month' , data = flight , hue ='year')
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
data = pd.read_csv('airlines_flights_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = pd.read_csv('airlines_flights_data.csv')
#
# NameError: name 'pd' is not defined

# %%
data.dropna()

# %%
sns.barplot(x = 'source_city' , y = 'index' , data = data)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
students = pd.read_csv("BUSinT.csv")



# students.set_index("roll_no",inplace=True)

students["class"] = students["roll_no"].str.split('/').str[1]
students["Total marks"] = 100
students["obt marks"] = students["exam1"]+students["exam2"]+students["final_exam"]
students["perc"] = students["obt marks"]/students["Total marks"]*100

def grades(score):
    if score >= 80:
        return "A"
    elif score >= 70:
        return "B"
    elif score >= 60:
        return "C"
    elif score >= 50:
        return "D"
    else:
        return "F"

students['grades'] = students["perc"].apply(grades)

# %%
students.head(0)
# Out:
# Empty DataFrame
# Columns: [roll_no, name, exam1, exam2, final_exam, class, Total marks, obt marks, perc, grades]
# Index: []

# %%
sns.barplot(y = 'perc' , x = 'class' , data = students , hue = 'grades')
sns?
# Out:
# Type:        module
# String form: <module 'seaborn' from 'C:\\Users\\munee\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\seaborn\\__init__.py'>
# File:        c:\users\munee\appdata\local\programs\python\python313\lib\site-packages\seaborn\__init__.py
# Docstring:   <no docstring>

# %%
sns.violinplot(x = 'day', y = 'total_bill' , data = tips , hue = 'day' , inner = 'point')
plt.show()
