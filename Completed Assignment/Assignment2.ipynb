# %% [markdown]
# ##	1) Write a Python program that asks the user to enter their age. Based on the input, classify the user as a "Minor" (below 18), "Adult" (18-60), or Senior Citizen" (above 60).

# %%
age = int(input("Enter your age: "))
if age < 18:
    print("Minor")
elif age <= 60:
  print("Adult")
elif age > 60:
  print("Senior Citizen")
else:
  print("Wrong input")
# Out:
# Enter your age: 61
# Senior Citizen

# %% [markdown]
# ## 2) Write a Python program that takes an integer input from the user and checks whether it is even or odd.

# %%
Num = int(input("Enter a number: "))
if Num % 2 == 0:
   print(f"{Num} is Even")
else:
   print(f"{Num} is Odd")
# Out:
# Enter a number: 45
# 45 is Odd

# %% [markdown]
# ## 3) Ask the user to enter their exam score (0-100). Based on the score, print the corresponding grade:
#
# ## A (90-100) B (80-89) C (70-79) D (60-69) F (Below 60)

# %%
Exam_score = int(input("Enter your exam score: "))
if Exam_score >= 90 and Exam_score <= 100:
  print("A")
elif Exam_score >= 80 and Exam_score <= 89:
  print("B")
elif Exam_score >= 70 and Exam_score <= 79:
  print("C")
elif Exam_score >= 60 and Exam_score <= 69:
  print("D")
elif Exam_score < 60:
  print("F")
else:
  print("Wrong input")
# Out:
# Enter your exam score: 101
# Wrong input

# %% [markdown]
# ## 4) Write a Python program that takes a number as input and determines whether it is positive, negative, or zero

# %%
Num = int(input("Enter a number: "))
if Num > 0:
  print("Positive")
elif Num < 0:
  print("Negative")
elif Num == 0:
  print("Zero")
else:
  print("Wrong input")
# Out:
# Enter a number: 000
# Zero

# %% [markdown]
# ## 5) Write a Python program that takes the user's age as input and prints whether they are eligible to vote (age 18 and above) or not.

# %%
age = int(input("Enter your age: "))
if age >= 18:
  print("You are eligible to vote")
else:
  print("You are not eligible to vote")

# %% [markdown]
# ## 6) Take three numbers as input from the user and determine the largest number among them.

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
if a > b and a > c:
  print(f"{a} is the largest number")
elif b > a and b > c:
  print(f"{b} is the largest number")
elif c > a and c > b:
  print(f"{c} is the largest number")
elif b == a and b == c:
  print("All numbers are same.")
else:
  print("Wrong input")
# Out:
# Enter first number: 20
# Enter second number: 20
# Enter third number: 20
# All numbers are same.

# %% [markdown]
# ## 7) Write a Python program that asks the user to enter a year and determines whether it is a leap year or not. (A year is a leap year if it is divisible by 4 but not divisible by 100, unless it is also divisible by 400).

# %%
year = int(input("Enter a year: "))
if year % 4 == 0 and year % 100 != 0 or year % 400 == 0 and year % 4 == 0:
  print(f"{year} is a leap year")
else:
  print(f"{year} is not a leap year")
# Out:
# Enter a year: 2028
# 2028 is a leap year

# %% [markdown]
# ## 8) Ask the user to enter a number between 1 and 7. Print the corresponding day of the week (1 = Sunday, 2 = Monday, etc.). If the input is out of range, print "Invalid input".

# %%
week = int(input("Enter a number between 1 and 7: "))
if week == 1:
  print("Sunday")
elif week == 2:
  print("Monday")
elif week == 3:
  print("Tuesday")
elif week == 4:
  print("Wednesday")
elif week == 5:
  print("Thursday")
elif week == 6:
  print("Friday")
elif week == 7:
  print("Saturday")
else:
  print("Invalid input")
# Out:
# Enter a number between 1 and 7: 8
# Invalid input

# %% [markdown]
# ## 9) Ask the user to enter an amount in PKR and convert it to Dollors

# %%
Amount_PKR = float(input("Enter an amount in Pakistan Rupees:"))
print(f"{Amount_PKR} PKR is equal to {Amount_PKR / 279.93} Dollars")
# Out:
# Enter an amount in Pakistan Rupees:1959.51
# 1959.51 PKR is equal to 7.0 Dollars

# %% [markdown]
# ## 10) Take an integer input and determine if it is a prime number only divisible by 1 and itself

# %%
Number = int(input("Enter a number: "))
if Number > 1:
  for i in range(2, Number):
    if Number % i == 0:
      print(f"{Number} is not a prime number")
      break
  else:
    print(f"{Number} is a prime number")
else:
    print(f"{Number} is a prime number")
# Out:
# Enter a number: 1

# %% [markdown]
# ## 11) Take a number as input and check whether it is divisible by both 5 and 11.

# %%
Number = int(input("Enter a number: "))
if Number % 5 == 0 and Number % 11 == 0:
  print(f"{Number} is divisible by both 5 and 11")
else:
  print(f"{Number} is not divisible by both 5 and 11")
# Out:
# Enter a number: 11
# 11 is not divisible by both 5 and 11

# %% [markdown]
# ## 12) Ask the user to input a single character. Determine whether it is uppercase or lowercase.

# %%
Alpha = input("Enter a Alphabet: ")
if Alpha.isupper():
  print(f"{Alpha} is uppercase")
elif Alpha.islower():
  print(f"{Alpha} is lowercase")
else:
  print("Wrong input")
# Out:
# Enter a Alphabet: A
# A is uppercase

# %% [markdown]
# ## 13) ask the user to input string Count the Number of Characters

# %%
word = input("Enter a Word: ")
print(f"The length of {word}  is {len(word)}")
# Out:
# Enter a Word: muneeb
# The length of muneeb  is 6

# %% [markdown]
# ## 14) Write a Python program that takes a string input from the user and prints it in uppercase using a string function

# %%
word = input("Enter a Word: ")
print(f"{word}  in uppercase is {word.upper()}")
# Out:
# Enter a Word: muneeb
# muneeb  in uppercase MUNEEB

# %% [markdown]
# ## 15) Take a sentence input from the user and replace all occurrences of a specific word with another word using the replace() function

# %%
sentence = input("Enter a sentence: ")
word = input("Enter a word to replace: ")
new_word = input("Enter a new word: ")
print(f"The new sentence is {sentence.replace(word, new_word)}")
# Out:
# Enter a sentence: dfgdfgdgdfgraeagfhdfgfs
# Enter a word to replace: d
# Enter a new word: f
# The new sentence is ffgffgfgffgraeagfhffgfs

# %% [markdown]
# ## 16) Write a Python program that asks the user to enter a string and checks whether it is numeric using the isnumeric() function.

# %%
string = input("Enter a string: ")
if string.isnumeric():
  print(f"{string} is numeric")
else:
  print(f"{string} is not numeric")
# Out:
# Enter a string: sddhhhh2 + fdsfs2vd2
# sddhhhh2 + fdsfs2vd2 is not numeric

# %% [markdown]
# ## 17) Write a Python program that removes extra spaces from the beginning and end of a string using the strip() function

# %%
word = input("Enter a word with spaces before the word and after the word: ")
print(f"The new word is {word.strip()}")
# Out:
# Enter a word with spaces before the word and after the word:      sadsa
# The new word is sadsa

# %% [markdown]
# ## 18) Take a sentence input and convert it into title case (capitalize the first letter of each word) using title().

# %%
sentence = input("Enter a sentence: ")
print(f"The title case of the sentence is '{sentence.title()}'")
# Out:
# Enter a sentence: take a sentence input .and convert it into ti.tle case (capitalize th.e first letter of each word). using title().
# The title case of the sentence is 'Take A Sentence Input .And Convert It Into Ti.Tle Case (Capitalize Th.E First Letter Of Each Word). Using Title().'
