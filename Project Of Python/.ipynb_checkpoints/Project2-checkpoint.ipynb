# %%
detail_dict = {}
i = 0
while True:
  print("""



          <<<<<<<--------Make account-------->>>>>>>""")
  while True:
    i += 1
    b=f"Name{i}"
    c=f"Address{i}"
    d=f"Phone{i}"
    e=f"Email{i}"
    f=f"Password{i}"
    g=f"Age{i}"
    h=f"Gender{i}"
    j=f"Qualification{i}"
    k=f"Country{i}"
    l=f"City{i}"


    choice = input("""

  1.Signup.
  2.Login.
  3.Exit.

  Choose: 1,2,3  :   """)
    if choice == "1":
      print("""



                <<<<<<----------SIGNUP---------->>>>>>""")
      email = input("Enter your email: ").lower()
      password = input("Enter your Password: ")
      name = input("Enter your name: ").capitalize()
      address = input("Enter your address: ")
      phone = input("Enter your phone number: ")
      age = input("Enter your age: ")
      gender = input("Enter your gender: ")
      qualification = input("Enter your qualification: ")
      country = input("Enter your country: ")
      city = input("Enter your city: ")
      detail_dict[b] = name
      detail_dict[c] = address
      detail_dict[d] = phone
      detail_dict[e] = email
      detail_dict[f] = password
      detail_dict[g] = age
      detail_dict[h] = gender
      detail_dict[j] = qualification
      detail_dict[k] = country
      detail_dict[l] = city
    elif choice == "2":
      print("""


                <<<<<<--------Login now-------->>>>>>

      """)
      user_email = input("Enter Email: ").lower()
      user_pass = input("Enter Password: ")
      if user_email in detail_dict.values():
        for num in range(1,i+1):
          em = f"Email{num}"
          pd = f"Password{num}"
          if user_email == detail_dict[em]:
            if user_pass == detail_dict[pd]:
              print("""



                    <<<<<-----WELCOME IN PROFILE---->>>>>

                    """)
              print(f"""  Name            :    {detail_dict[f"Name{num}"]}""")
              print(f"""  Address         :    {detail_dict[f"Address{num}"]}""")
              print(f"""  Phone           :    {detail_dict[f"Phone{num}"]}""")
              print(f"""  Email           :    {detail_dict[f"Email{num}"]}""")
              print(f"""  Password        :    {detail_dict[f"Password{num}"]}""")
              print(f"""  Age             :    {detail_dict[f"Age{num}"]}""")
              print(f"""  Gender          :    {detail_dict[f"Gender{num}"]}""")
              print(f"""  Qualification   :    {detail_dict[f"Qualification{num}"]}""")
              print(f"""  Country         :    {detail_dict[f"Country{num}"]}""")
              print(f"""  City            :    {detail_dict[f"City{num}"]}""")
              break
            else:
              print("Incorrect Password")
      else:
        print("""

            Sorry, looks like that’s the wrong email or password.

                    Please Signup""")
    elif choice == "3":
      print("""



             <<<<<<----------Thanks.---------->>>>>>""")
      break
    else:
      print("Invalid Input")
  break
# Out:
#           <<<<<<<--------Make account-------->>>>>>>
#
#
#   1.Signup.
#   2.Login.
#   3.Exit.
#
#   Choose: 1,2,3  :   1
#
#
#
#
#                 -------------------SIGNUP-------------------
# Enter your email: kjhgfd
# Enter your Password: jhgfds
# Enter your name: kjhgfd
# Enter your address: jhgfd
# Enter your phone number: kjhgfds
# Enter your age: jhgfds
# Enter your gender: jhgfds
# Enter your qualification: jhgfd
# Enter your country: jhgfd
# Enter your city: jhgfd
#
#
#   1.Signup.
#   2.Login.
#   3.Exit.
#
#   Choose: 1,2,3  :   1
#
#
#
#
#                 -------------------SIGNUP-------------------
# Enter your email: mnbv
# Enter your Password: mnbvc
# Enter your name: nbnvcx
# Enter your address: nbvc
# Enter your phone number: nbvc
# Enter your age: mnbvc
# Enter your gender: mnbvc
# Enter your qualification: mnbvcx
# Enter your country: nbvcx
# Enter your city: bvc
#
#
#   1.Signup.
#   2.Login.
#   3.Exit.
#
#   Choose: 1,2,3  :   2
#
#
#
# ...

# %%
detail_dict = {}
while True:
  print("""



          <<<<<<<--------Make account-------->>>>>>>""")
  for i in range(1,6):
    a=f"Name{i}"
    b=f"Address{i}"
    c=f"Phone{i}"
    d=f"Email{i}"
    e=f"Password{i}"

    choice = input("""

  1.Signup.
  2.Login.
  3.Exit.

  Choose: 1,2,3  :   """)
    if choice == "1":
      name = input("Enter your name: ").capitalize()
      address = input("Enter your address: ")
      phone = input("Enter your phone number: ")
      email = input("Enter your email: ").lower()
      password = input("Enter your Password: ")
      detail_dict[a] = name
      detail_dict[b] = address
      detail_dict[c] = phone
      detail_dict[d] = email
      detail_dict[e] = password
    elif choice == "2":
      print("""


                <<<<<<<--------Login now-------->>>>>>>""")
      user_email = input("Enter Email: ").lower()
      user_pass = input("Enter Password: ")
      if user_email in detail_dict.values():
        if user_email == detail_dict["Email1"]:
          if user_pass == detail_dict["Password1"]:
            print("""



                    <<<<<-----WELCOME IN PROFILE---->>>>>""")
            print(f"""  Name      :    {detail_dict['Name1']}""")
            print(f"""  Address      :    {detail_dict['Address1']}""")
            print(f"""  Phone      :    {detail_dict['Phone1']}""")
            print(f"""  Email      :    {detail_dict['Email1']}""")
            print(f"""  Password      :    {detail_dict['Password1']}""")
          else:
              print("Incorrect Password")
        elif user_email == detail_dict["Email2"]:
          if user_pass == detail_dict["Password2"]:
             print("""<<<<<-----WELCOME IN PROFILE---->>>>>""")
             print(f""" Name      :    {detail_dict['Name2']}""")
             print(f""" Address      :    {detail_dict['Address2']}""")
             print(f""" Phone      :    {detail_dict['Phone2']}""")
             print(f""" Email      :    {detail_dict['Email2']}""")
             print(f""" Password      :    {detail_dict['Password2']}""")
          else:
             print("Incorrect Password")
        elif user_email == detail_dict["Email3"]:
          if user_pass == detail_dict["Password3"]:
             print("""<<<<<-----WELCOME IN PROFILE---->>>>>""")
             print(f""" Name      :    {detail_dict['Name3']}""")
             print(f""" Address      :    {detail_dict['Address3']}""")
             print(f""" Phone      :    {detail_dict['Phone3']}""")
             print(f""" Email      :    {detail_dict['Email3']}""")
             print(f""" Password      :    {detail_dict['Password3']}""")
          else:
             print("Incorrect Password")
        elif user_email == detail_dict["Email4"]:
            if user_pass == detail_dict["Password4"]:
              print("""<<<<<-----WELCOME IN PROFILE---->>>>>""")
              print(f"""  Name      :    {detail_dict['Name4']}""")
              print(f"""  Address      :    {detail_dict['Address4']}""")
              print(f"""  Phone      :    {detail_dict['Phone4']}""")
              print(f"""  Email      :    {detail_dict['Email4']}""")
              print(f"""  Password      :    {detail_dict['Password4']}""")
            else:
              print("Incorrect Password")
        elif user_email == detail_dict["Email5"]:
            if user_pass == detail_dict["Password5"]:
              print("""<<<<<-----WELCOME IN PROFILE---->>>>>""")
              print(f"""  Name      :    {detail_dict['Name5']}""")
              print(f"""  Address      :    {detail_dict['Address5']}""")
              print(f"""  Phone      :    {detail_dict['Phone5']}""")
              print(f"""  Email      :    {detail_dict['Email5']}""")
              print(f"""  Password      :    {detail_dict['Password5']}""")
            else:
              print("Incorrect Password")
      else:
        print("Sorry, looks like that’s the wrong email or password.")
    elif choice == "3":
      print("""



             -------------------Thanks.-------------------""")
      break
    else:
      print("Invalid Input")
  break
# Out:
#           <<<<<<<--------Make account-------->>>>>>>
#
#
#   1.Signup.
#   2.Login.
#   3.Exit.
#
#   Choose: 1,2,3  :   1
# Enter your name: fghjkkjh
# Enter your address: kjhkjhh
# Enter your phone number: jdhsfaa
# Enter your email: jghfds
# Enter your Password: kjhgf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-70ce565a4df8> in <cell line: 0>()
#      13     e=f"Password{i}"
#      14
# ---> 15     choice = input("""
#      16
#      17   1.Signup.
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...
