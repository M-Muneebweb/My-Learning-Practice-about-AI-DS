# %%
import numpy as np
from numpy import random

line = np.random.randint(100, size = (10,10))

multiplied = line*3

even = line[(line%2==0)]

odd = line[(line%2!=0)]

colunms = int(len(even)/2)

reshape = even.reshape(2,colunms)


print(multiplied)
print()
print()
print()
# Out:
# [[147 114 225 129 264 282  66 297  42 288]
#  [ 33  21  78 111 255 243 267 165 294  30]
#  [273 141 240 102 273 141  24  18  30  51]
#  [210 276 219 291  45 102 120   3 147 111]
#  [243 153 198 243  48  87 192  24 261  21]
#  [237 276  36 180  15 192 189 297 192  69]
#  [ 15 186 204 210 153 228   3   9 243 138]
#  [ 48 213 240  99 288 255 105 189  21 105]
#  [ 48 105  57 270 282  21 105  63  15 126]
#  [ 18  90  75   3 135 135   0 129 204  54]]

# %%
 m = np.random.randint(100,size = (1,1))

# %%
m.sort(axis = 1)

# %%
print(len(m))
#m.reshape
m =m.flatten()
# Out:
# 1

# %%
random.choice(m,size=2)
# Out:
# array([9, 9], dtype=int32)

# %%
m.min()
# Out:
# np.int32(9)
