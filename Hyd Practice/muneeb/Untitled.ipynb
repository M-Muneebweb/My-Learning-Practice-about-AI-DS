# %% [raw]
#      *
#     * *
#    * * *
#   * * * *
#  * * * * *
# * * * * * *

# %%
for i in range(1,7):
    print(" "*(7-i)," *"*i)
# Out:
#         *
#        * *
#       * * *
#      * * * *
#     * * * * *
#    * * * * * *

# %% [raw]
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *

# %%
for i in range(1,7):
    print(" *"*i)
# Out:
#  *
#  * *
#  * * *
#  * * * *
#  * * * * *
#  * * * * * *

# %% [raw]
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range(1,7):
    print(" *"*i)
for i in range(5,0 , -1):
    print(" *"*i)
# Out:
#  *
#  * *
#  * * *
#  * * * *
#  * * * * *
#  * * * * * *
#  * * * * *
#  * * * *
#  * * *
#  * *
#  *

# %% [raw]
#           *
#         * *
#       * * *
#     * * * *
#   * * * * *
# * * * * * *

# %%
for i in range(1,7):
    print("  "*(6-i)," *"*i)
# Out:
#             *
#           * *
#         * * *
#       * * * *
#     * * * * *
#   * * * * * *

# %% [raw]
#           *
#         * *
#       * * *
#     * * * *
#   * * * * *
# * * * * * *
#   * * * * *
#     * * * *
#       * * *
#         * *
#           *

# %%
for i in range(1,7):
    print("  "*(6-i)," *"*i)
for i in range(5,0 , -1):
    print("  "*(6-i)," *"*i)
# Out:
#             *
#           * *
#         * * *
#       * * * *
#     * * * * *
#   * * * * * *
#     * * * * *
#       * * * *
#         * * *
#           * *
#             *
