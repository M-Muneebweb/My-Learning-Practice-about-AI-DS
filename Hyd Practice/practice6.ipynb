# %%
import numpy as np
import pandas as pd

# %%
a = [[1,2,3,4,5],[2,3,5,7,8]]

# %%
myarray = np.array(a)

# %%
df = pd.DataFrame(a)

# %%
df
# Out:
#         a  b  c  d  e
# First   1  2  3  4  5
# Second  2  3  5  7  8

# %%
df = pd.DataFrame(a,columns = ["a","b","c","d","e"])

# %%
df
# Out:
#         a  b  c  d  e
# First   1  2  3  4  5
# Second  2  3  5  7  8

# %%
df
# Out:
#         a  b  c  d  e
# First   1  2  3  4  5
# Second  2  3  5  7  8

# %%
print(df)
# Out:
#         a  b  c  d  e
# First   1  2  3  4  5
# Second  2  3  5  7  8

# %%
pd.DataFrame?
# Out:
# Init signature:
# pd.DataFrame(
#     data=None,
#     index: 'Axes | None' = None,
#     columns: 'Axes | None' = None,
#     dtype: 'Dtype | None' = None,
#     copy: 'bool | None' = None,
# ) -> 'None'
# Docstring:
# Two-dimensional, size-mutable, potentially heterogeneous tabular data.
#
# Data structure also contains labeled axes (rows and columns).
# Arithmetic operations align on both row and column labels. Can be
# thought of as a dict-like container for Series objects. The primary
# pandas data structure.
#
# Parameters
# ----------
# data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#     Dict can contain Series, arrays, constants, dataclass or list-like objects. If
#     data is a dict, column order follows insertion-order. If a dict contains Series
#     which have an index defined, it is aligned by its index. This alignment also
#     occurs if data is a Series or a DataFrame itself. Alignment is done on
#     Series/DataFrame inputs.
#
# ...

# %%
df = pd.DataFrame(a,columns = ["a","b","c","d","e"],index = ["First","Second"],dtype = str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, First to Second
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       2 non-null      object
#  1   b       2 non-null      object
#  2   c       2 non-null      object
#  3   d       2 non-null      object
#  4   e       2 non-null      object
# dtypes: object(5)
# memory usage: 204.0+ bytes

# %%
df = pd.DataFrame(a,columns = ["a","b","c","d","e"],index = ["First","Second"])

# %%
student = [{
           "std-1":{"Name":"Muneeb","Father/Name":"Rashid","Age":16,"Gender":"Male"},
           "std-2":{"Name":"Huzaifa","Father/Name":"Kashif","Age":15,"Gender":"Male"},
           "std-3":{"Name":"Owais","Father/Name":"Atif","Age":18,"Gender":"Male"},
           "std-4":{"Name":"Basit","Father/Name":"Hanif","Age":14,"Gender":"Male"},
           "std-5":{"Name":"Omer","Father/Name":"Sikandar","Age":16,"Gender":"Male"}
}
          ]


students = pd.DataFrame(student)

students
# Out:
#                                                std-1  \
# 0  {'Name': 'Muneeb', 'Father/Name': 'Rashid', 'A...
#
#                                                std-2  \
# 0  {'Name': 'Huzaifa', 'Father/Name': 'Kashif', '...
#
#                                                std-3  \
# 0  {'Name': 'Owais', 'Father/Name': 'Atif', 'Age'...
#
#                                                std-4  \
# 0  {'Name': 'Basit', 'Father/Name': 'Hanif', 'Age...
#
#                                                std-5
# 0  {'Name': 'Omer', 'Father/Name': 'Sikandar', 'A...

# %%
student = [
           {"Name":"Muneeb","Father/Name":"Rashid","Age":16,"Gender":"Male"},
           {"Name":"Huzaifa","Father/Name":"Kashif","Age":15,"Gender":"Male"},
           {"Name":"Owais","Father/Name":"Atif","Age":18,"Gender":"Male"},
           {"Name":"Basit","Father/Name":"Hanif","Age":14,"Gender":"Male"},
           {"Name":"Omer","Father/Name":"Sikandar","Age":16,"Gender":"Male"}
          ]


students = pd.DataFrame(student)

students["Age"] = students["Age"].astype(float)

# %%
students
# Out:
#       Name Father/Name   Age Gender
# 0   Muneeb      Rashid  16.0   Male
# 1  Huzaifa      Kashif  15.0   Male
# 2    Owais        Atif  18.0   Male
# 3    Basit       Hanif  14.0   Male
# 4     Omer    Sikandar  16.0   Male

# %%
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         5 non-null      object
#  1   Father/Name  5 non-null      object
#  2   Age          5 non-null      float64
#  3   Gender       5 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 288.0+ bytes

# %%
students["Age"] = students["Age"].astype(float)

# %%
num = np.array([[1,2,3,4,5,6],[5,6,"F",8,1,7],[8,"y",4,3,"",7],[9,"h",7,"#",5,8]])

# %%
num = pd.DataFrame(num,columns = ["a","b","c","d","e","f"],index = ["A","B","C","D"])
num
# Out:
#    a  b  c  d  e  f
# A  1  2  3  4  5  6
# B  5  6  F  8  1  7
# C  8  y  4  3     7
# D  9  h  7  #  5  8

# %%
num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, A to D
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       4 non-null      object
#  1   b       4 non-null      object
#  2   c       4 non-null      object
#  3   d       4 non-null      object
#  4   e       4 non-null      object
#  5   f       4 non-null      object
# dtypes: object(6)
# memory usage: 224.0+ bytes

# %%
num.c
# Out:
# A    3
# B    F
# C    4
# D    7
# Name: c, dtype: object

# %%
num
# Out:
#    a  b  c  d  e  f
# A  1  2  3  4  5  6
# B  5  6  F  8  1  7
# C  8  y  4  3     7
# D  9  h  7  #  5  8

# %%
myfile = pd.read_csv("Titanic-Dataset.csv")

# %%
myfile.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
myfile.describe().loc["mean"]
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# Name: mean, dtype: float64

# %%
num.describe()
# Out:
#         a  b  c  d  e  f
# count   4  4  4  4  4  4
# unique  4  4  4  4  3  3
# top     1  2  3  4  5  7
# freq    1  1  1  1  2  2

# %%
num.describe().loc["mean"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mean'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 num.describe().loc["mean"]
#
# ...
