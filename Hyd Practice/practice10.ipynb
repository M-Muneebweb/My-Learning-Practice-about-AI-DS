# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression as LR
from sklearn.model_selection import train_test_split
import kagglehub

dib = load_diabetes()

data = pd.DataFrame(dib.data, columns=dib.feature_names)

y = dib.target

xtrain , xtest , ytrain , ytest = train_test_split(data , y , test_size=0.2, random_state=42)

model = LR()

model.fit(xtrain , ytrain)



predict_train = model.predict(xtrain)
plt.scatter(x = xtrain['s6'] , y = ytrain, alpha = 0.3)
plt.scatter(x = xtrain['s6'] , y = predict_train, alpha = 0.3)

# %%
path = kagglehub.dataset_download("iammustafatz/diabetes-prediction-dataset")

path = f"{path}\\diabetes_prediction_dataset.csv"

data2 = pd.read_csv(path)
y = data2['blood_glucose_level']
x = data2.drop(['diabetes' , 'blood_glucose_level' , 'gender' , 'smoking_history'], axis=1)

xtrain , xtest , ytrain , ytest = train_test_split(x , y , test_size=0.2, random_state=42)

model2 = LR()

model2.fit(xtrain , ytrain)

print(model2.predict(xtest))
# Out:
# [133.77254104 128.23398345 127.32898562 ... 133.59246327 154.77225655
#  137.84129664]
