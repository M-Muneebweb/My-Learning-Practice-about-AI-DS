# %%
print("hello world")
# Out:
# hello worl

# %% [raw]
#      *
#     * *
#    * * *
#   * * * *
#  * * * * *
# * * * * * *

# %% [raw]
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *

# %%
for i in range (0,6):
    for j in range (0,i+1):
        print(" *")
# Out:
#  *
#  *
#  *
#  *
#  *
#  *
#  *
#  *
#  *
#  *
#  *
#  *
#  *
#  *
#  *
#  *
#  *
#  *
#  *
#  *
#  *

# %% [raw]
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [raw]
#           *
#         * *
#       * * *
#     * * * *
#   * * * * *
# * * * * * *

# %% [raw]
#           *
#         * *
#       * * *
#     * * * *
#   * * * * *
# * * * * * *
#   * * * * *
#     * * * *
#       * * *
#         * *
#           *
