# %%
equation = input("Enter your equation for evaluate")

if '*' in equation:
    values = equation.split("*")
elif '*' in equation:
    values = equation.split("+")
elif '*' in equation:
    values = equation.split("+")
elif '*' in equation:
    values = equation.split("+")
elif '*' in equation:
    values = equation.split("+")
