# %% [markdown]
# Task:
# Create a class named as DataBaseManagment contains :
# 1. Add a method to add user data in DataBase.txt
# 2.  Add a method   to delete user data by email from DataBase.txt
# 3. Add _repr_ Magic method to get email as a parameter and return the detail of that user
# 4. Add a method to get all users in a list from DataBase.txt file (hint: returns List of user details)

# %%
class DataBaseManagment:
    def add_data(self,Name,Email,Age,Gender):
        file = open("DataBase.txt","a+")
        file.write(f"{Name},{Email},{Age},{Gender}\n")
        file.seek(0)
        file.close()
    def del_data(self,email):
        ffile = open("DataBase.txt","r")
        d_list = []
        for line in ffile.readlines():
            if email != line.split(",")[1].strip():
                d_list.append(line)
                
            else:
                continue
        else:
            ffile.close()
            ffile = open("DataBase.txt","w")
            ffile.writelines(d_list)
            ffile.close()
    def __repr__(self,Email="fatima_01@yahoo.com"):
        file = open("DataBase.txt","r")
        for line1 in file.readlines():
            if Email == line1.split(",")[1].strip():
                return print(f"""
                Name   : {line1.split(",")[0].strip()}
                Email  : {line1.split(",")[1].strip()}
                Age    : {line1.split(",")[2].strip()}
                Gender : {line1.split(",")[3].strip()}""")
                break
        file.close()
    def all_users(self):
        da_list = []
        file = open("DataBase.txt","r")
        for line in file.readlines():
            da_list.append(line.replace("\n",""))
        print(da_list)
                

p1 = DataBaseManagment()


p1.add_data("Ali", "ali123@gmail.com", 17, "Male")
p1.add_data("Fatima", "fatima_01@yahoo.com", 19, "Female")
p1.add_data("Ahmed", "ahmed.khan@mail.com", 18, "Male")
p1.add_data("Zainab", "zainab_star@outlook.com", 20, "Female")
p1.add_data("Hassan", "hassan.dev@gmail.com", 21, "Male")
p1.add_data("Ayesha", "ayesha_786@hotmail.com", 22, "Female")
p1.add_data("Usman", "usman007@gmail.com", 23, "Male")
p1.add_data("Laiba", "laiba_love@gmail.com", 18, "Female")
p1.add_data("Saad", "saadcool@yahoo.com", 19, "Male")
p1.add_data("Mariam", "mariamxoxo@mail.com", 20, "Female")


p1.del_data("hassan.dev@gmail.com")

p1.all_users()

print(p1)


p1.__repr__()

# %%
p1.add_data("Ali", "ali123@gmail.com", 17, "Male")
p1.add_data("Fatima", "fatima_01@yahoo.com", 19, "Female")
p1.add_data("Ahmed", "ahmed.khan@mail.com", 18, "Male")
p1.add_data("Zainab", "zainab_star@outlook.com", 20, "Female")
p1.add_data("Hassan", "hassan.dev@gmail.com", 21, "Male")
p1.add_data("Ayesha", "ayesha_786@hotmail.com", 22, "Female")
p1.add_data("Usman", "usman007@gmail.com", 23, "Male")
p1.add_data("Laiba", "laiba_love@gmail.com", 18, "Female")
p1.add_data("Saad", "saadcool@yahoo.com", 19, "Male")
p1.add_data("Mariam", "mariamxoxo@mail.com", 20, "Female")


p1.del_data("hassan.dev@gmail.com")

p1.all_users()

print(p1)


p1.__repr__()

# %%
p1.del_data("hassan.dev@gmail.com")

# %%
p1.all_users()
# Out:
# ['Ali,ali123@gmail.com,17,Male', 'Fatima,fatima_01@yahoo.com,19,Female', 'Ahmed,ahmed.khan@mail.com,18,Male', 'Zainab,zainab_star@outlook.com,20,Female', 'Hassan,hassan.dev@gmail.com,21,Male', 'Ayesha,ayesha_786@hotmail.com,22,Female', 'Usman,usman007@gmail.com,23,Male', 'Saad,saadcool@yahoo.com,19,Male', 'Mariam,mariamxoxo@mail.com,20,Female']

# %%
print(p1)
# Out:
#                 Name : Fatima
#                 Email : fatima_01@yahoo.com
#                 Age : 19
#                 Gender : Female

# %%
p1.__repr__()
# Out:
#                 Name   : Fatima
#                 Email  : fatima_01@yahoo.com
#                 Age    : 19
#                 Gender : Female
