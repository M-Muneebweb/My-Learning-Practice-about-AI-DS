# %% [markdown]
# # Spotify_Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('SpotifyFeatures.csv')
col = np.array(data.columns).reshape(-1,1)

# %%
data.head(5)
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %%
data.tail(5)
# Out:
#        genre               artist_name                      track_name  \
# 232720  Soul                     Slave                    Son Of Slide
# 232721  Soul  Jr Thomas & The Volcanos                    Burning Fire
# 232722  Soul              Muddy Waters  (I'm Your) Hoochie Coochie Man
# 232723  Soul                   R.LUM.R                   With My Words
# 232724  Soul            Mint Condition  You Don't Have To Hurt No More
#
#                       track_id  popularity  acousticness  danceability  \
# 232720  2XGLdVl7lGeq8ksM6Al7jT          39       0.00384         0.687
# 232721  1qWZdkBl4UVPj9lK6HuuFM          38       0.03290         0.785
# 232722  2ziWXUmQLrXTiYjCg2fZ2t          47       0.90100         0.517
# 232723  6EFsue2YbIG4Qkq8Zr9Rir          44       0.26200         0.745
# 232724  34XO9RwPMKjbvRry54QzWn          35       0.09730         0.758
#
#         duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 232720       326240   0.714          0.544000   D    0.0845   -10.626  Major
# 232721       282447   0.683          0.000880   E    0.2370    -6.944  Minor
# 232722       166960   0.419          0.000000   D    0.0945    -8.282  Major
# 232723       222442   0.704          0.000000   A    0.3330    -7.137  Major
# 232724       323027   0.470          0.000049  G#    0.0836    -6.708  Minor
#
#         speechiness    tempo time_signature  valence
# 232720       0.0316  115.542            4/4    0.962
# 232721       0.0337  113.830            4/4    0.969
# 232722       0.1480   84.135            4/4    0.813
# 232723       0.1460  100.031            4/4    0.489
# 232724       0.0287  113.897            4/4    0.479

# %%
data.describe()
# Out:
#           popularity   acousticness   danceability   duration_ms  \
# count  232725.000000  232725.000000  232725.000000  2.327250e+05
# mean       41.127502       0.368560       0.554364  2.351223e+05
# std        18.189948       0.354768       0.185608  1.189359e+05
# min         0.000000       0.000000       0.056900  1.538700e+04
# 25%        29.000000       0.037600       0.435000  1.828570e+05
# 50%        43.000000       0.232000       0.571000  2.204270e+05
# 75%        55.000000       0.722000       0.692000  2.657680e+05
# max       100.000000       0.996000       0.989000  5.552917e+06
#
#               energy  instrumentalness       liveness       loudness  \
# count  232725.000000     232725.000000  232725.000000  232725.000000
# mean        0.570958          0.148301       0.215009      -9.569885
# std         0.263456          0.302768       0.198273       5.998204
# min         0.000020          0.000000       0.009670     -52.457000
# 25%         0.385000          0.000000       0.097400     -11.771000
# 50%         0.605000          0.000044       0.128000      -7.762000
# 75%         0.787000          0.035800       0.264000      -5.501000
# max         0.999000          0.999000       1.000000       3.744000
#
#          speechiness          tempo        valence
# count  232725.000000  232725.000000  232725.000000
# mean        0.120765     117.666585       0.454917
# std         0.185518      30.898907       0.260065
# min         0.022200      30.379000       0.000000
# 25%         0.036700      92.959000       0.237000
# 50%         0.050100     115.778000       0.444000
# 75%         0.105000     139.054000       0.660000
# max         0.967000     242.903000       1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   genre             232725 non-null  object
#  1   artist_name       232725 non-null  object
#  2   track_name        232724 non-null  object
#  3   track_id          232725 non-null  object
#  4   popularity        232725 non-null  int64
#  5   acousticness      232725 non-null  float64
#  6   danceability      232725 non-null  float64
#  7   duration_ms       232725 non-null  int64
#  8   energy            232725 non-null  float64
#  9   instrumentalness  232725 non-null  float64
#  10  key               232725 non-null  object
#  11  liveness          232725 non-null  float64
#  12  loudness          232725 non-null  float64
#  13  mode              232725 non-null  object
#  14  speechiness       232725 non-null  float64
#  15  tempo             232725 non-null  float64
#  16  time_signature    232725 non-null  object
#  17  valence           232725 non-null  float64
# dtypes: float64(9), int64(2), object(7)
# memory usage: 32.0+ MB

# %%
print(data.shape)
# Out:
# (232725, 18)

# %%
grouped = data.groupby('genre')
genre_means = grouped[['popularity','energy','danceability']].mean()
pd.DataFrame(genre_means)
# Out:
#                   popularity    energy  danceability
# genre
# A Capella           9.302521  0.250313      0.412252
# Alternative        50.213430  0.711519      0.541898
# Anime              24.258729  0.665356      0.472090
# Blues              34.742879  0.606171      0.528232
# Children's Music    4.252637  0.396880      0.697475
# Children’s Music   54.659040  0.706616      0.541843
# Classical          29.282195  0.177984      0.305958
# Comedy             21.342630  0.676094      0.559038
# Country            46.100416  0.636318      0.577038
# Dance              57.275256  0.698067      0.638191
# Electronic         38.056095  0.739299      0.619542
# Folk               49.940209  0.491733      0.527276
# Hip-Hop            58.423131  0.643275      0.718808
# Indie              54.701561  0.581002      0.566821
# Jazz               40.824383  0.472776      0.585638
# Movie              12.174097  0.370703      0.491186
# Opera              13.335628  0.168779      0.290650
# Pop                66.590667  0.642208      0.640236
# R&B                52.308719  0.564248      0.642125
# Rap                60.533795  0.650520      0.697244
# Reggae             35.589328  0.635749      0.699271
# Reggaeton          37.742915  0.748836      0.731260
# Rock               59.619392  0.683670      0.538292
# Ska                28.612351  0.815585      0.526799
# Soul               47.027836  0.532506      0.617645
# Soundtrack         33.954800  0.221110      0.265616
# World              35.524077  0.506453      0.443293

# %%
print(data.isnull().sum())
print(data.isna().sum())
# Out:
# genre               0
# artist_name         0
# track_name          1
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64
# genre               0
# artist_name         0
# track_name          1
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64

# %%
data.dropna( axis = 0 , inplace=True)

# %% [markdown]
# ### Removing Duplicated values

# %%
print(f"Dublicated Songs {data.duplicated(subset='track_id').sum()}")
# Out:
# Dublicated Songs 55951

# %%
data.drop_duplicates(subset='track_id',inplace=True)
print(f"After Cleaning data Size: {len(data)} \nand Dublicated Songs {data.duplicated(subset='track_id').sum()}")
# Out:
# After Cleaning data Size: 176773
# and Dublicated Songs 0

# %% [markdown]
# #### Finding average duration in minutes

# %%
av_min = round(float(data['duration_ms'].mean())/60000, 1)
print(f"{av_min} minutes")
# Out:
# 3.9 minutes

# %% [markdown]
# #### finding top ten Songs base on popularity

# %%
popularity = list(data.sort_values(by = 'popularity' , ascending=False).head(10)['popularity'])
artist_name = list(data.sort_values(by = 'popularity' , ascending=False).head(10)['artist_name'])
track_name = list(data.sort_values(by = 'popularity' , ascending=False).head(10)['track_name'])
track_id = list(data.sort_values(by = 'popularity' , ascending=False).head(10)['track_id'])
count = 1
for a,b,c,d in zip(popularity , artist_name , track_name , track_id):
    print(f"""    Popularity is: {a}
    Artist Name is: {b}
    Track Name is: {c}
    Track ID is: {d}
    Rank is: {count}

    
{"*"*25}
    """)
    count = count + 1
# Out:
#     Popularity is: 100
#     Artist Name is: Ariana Grande
#     Track Name is: 7 rings
#     Track ID is: 14msK75pk3pA33pzPVNtBF
#     Rank is: 1
#
#
# *************************
#
#     Popularity is: 99
#     Artist Name is: Post Malone
#     Track Name is: Wow.
#     Track ID is: 6MWtB6iiXyIwun0YzU6DFP
#     Rank is: 2
#
#
# *************************
#
#     Popularity is: 99
#     Artist Name is: Ariana Grande
#     Track Name is: break up with your girlfriend, i'm bored
#     Track ID is: 4kV4N9D1iKVxx1KLvtTpjS
#     Rank is: 3
#
#
# *************************
#
#     Popularity is: 98
#     Artist Name is: Daddy Yankee
#     Track Name is: Con Calma
#     Track ID is: 5w9c2J52mkdntKOmRLeM2m
#     Rank is: 4
#
#
# *************************
#
#     Popularity is: 97
#     Artist Name is: Post Malone
#     Track Name is: Sunflower - Spider-Man: Into the Spider-Verse
#     Track ID is: 3KkXRkHbMCARz0aVfEt68P
#     Rank is: 5
#
#
# *************************
#
#     Popularity is: 97
#     Artist Name is: Ava Max
#     Track Name is: Sweet but Psycho
#     Track ID is: 25sgk305KZfyuqVBQIahim
#     Rank is: 6
#
#
# *************************
#
#     Popularity is: 97
#     Artist Name is: Halsey
#     Track Name is: Without Me
#     Track ID is: 5p7ujcrUXASCNwRaWNHR1C
#     Rank is: 7
#
#
# *************************
#
#     Popularity is: 97
#     Artist Name is: Sam Smith
#     Track Name is: Dancing With A Stranger (with Normani)
#     Track ID is: 6Qs4SXO9dwPj5GKvVOv8Ki
#     Rank is: 8
#
#
# *************************
#
#     Popularity is: 97
#     Artist Name is: Marshmello
#     Track Name is: Happier
#     Track ID is: 2dpaYNEQHiRxtZbfNsse99
#     Rank is: 9
#
#
# *************************
#
#     Popularity is: 97
#     Artist Name is: Pedro Capó
#     Track Name is: Calma - Remix
#     Track ID is: 5iwz1NiezX7WWjnCgY5TH4
#     Rank is: 10
#
#
# *************************

# %% [markdown]
# #### Calculate mode Values Counts

# %%
data['mode'].value_counts()
# Out:
# mode
# Major    116618
# Minor     60155
# Name: count, dtype: int64

# %% [markdown]
# #### Calculate Genre Values Counts

# %%
data['genre'].value_counts()
# Out:
# genre
# Comedy              9674
# Electronic          9149
# Alternative         9095
# Anime               8935
# Classical           8711
# Reggae              8687
# Reggaeton           8549
# Blues               8496
# Soundtrack          8480
# Opera               8280
# Folk                8048
# Jazz                8039
# Ska                 8017
# Dance               7982
# World               7972
# Movie               7802
# Hip-Hop             7413
# Country             7383
# Children's Music    5402
# R&B                 5353
# Soul                4430
# Indie               3318
# Pop                 2417
# Rock                2227
# Rap                 1456
# Children’s Music    1339
# A Capella            119
# Name: count, dtype: int64

# %% [markdown]
# ## Visualization

# %%
sns.countplot(data = data , x = 'mode')
plt.savefig('graph1')

# %%
sns.countplot(data = data , x = 'key')
plt.savefig('graph2')

# %%
sns.countplot(data = data , x = 'time_signature')
plt.savefig('graph3')

# %%
sns.boxplot(data = data, y = 'popularity', hue = 'mode')
plt.savefig('graph4')

# %%
sns.scatterplot(data = data, x = 'duration_ms', y = 'popularity')
plt.savefig('graph5')

# %%
sns.heatmap(data[['popularity','acousticness','danceability','duration_ms','energy','instrumentalness','liveness','loudness','speechiness','tempo','valence']].corr(),annot=True)
plt.savefig('graph6')

# %%
sns.scatterplot(data = data , x = 'energy' , y = 'danceability' , hue='mode')
plt.legend(loc='upper right')
plt.savefig('graph7')
