# %% [markdown]
# # TASK Ecommerce
#
# - A Complete Annual Report for every year (Total sale, Most selling category, most selling product)
# - A Complete Monthly Report for every month (Total sale, Most selling category, most selling product)
# - Most re-visited customers
# - Most sailing category in complete years
# - List of all categrpries
# - Names of customers who had spented more than 200$ on our store
# - No of customers below 30, 50, 80 on every category

# %%
import numpy as np
import pandas as pd
# import files
ord_file = pd.read_csv("orders.csv")
csmer_file = pd.read_csv("customers.csv")
prd_file = pd.read_csv("products.csv")

ord_file["order_date"] = pd.to_datetime(ord_file["order_date"])
ord22 = ord_file[ord_file["order_date"].dt.year == 2022]
ord23 = ord_file[ord_file["order_date"].dt.year == 2023]
ord24 = ord_file[ord_file["order_date"].dt.year == 2024]

# %%
str(ord22['product_id']).split("P")[1].strip().split('\n')[0]
# Out:
# '022'

# %%
str(prd_file['product_id']).split("P")[1].strip().split('\n')[0]
# Out:
# '001'

# %%
np.array(pd.DataFrame(ord22).product_id)
# Out:
# array(['P022', 'P090', 'P021', 'P076', 'P073', 'P079', 'P046', 'P088',
#        'P063', 'P053', 'P009', 'P041', 'P087', 'P096', 'P073', 'P086',
#        'P067', 'P056', 'P045', 'P072', 'P002', 'P061', 'P022', 'P063',
#        'P043', 'P065', 'P083', 'P031', 'P057', 'P012', 'P041', 'P096',
#        'P052', 'P072', 'P012', 'P080', 'P066', 'P084', 'P044', 'P007',
#        'P059', 'P099', 'P061', 'P058', 'P098', 'P044', 'P082', 'P067',
#        'P014', 'P022', 'P092', 'P033', 'P025', 'P051', 'P025', 'P097',
#        'P082', 'P099', 'P085', 'P065', 'P064', 'P095', 'P056', 'P066',
#        'P075', 'P017', 'P085', 'P042', 'P050', 'P089', 'P051', 'P038',
#        'P018', 'P078', 'P090', 'P041', 'P028', 'P080', 'P045', 'P084',
#        'P070', 'P015', 'P062', 'P086', 'P096', 'P055', 'P014', 'P019',
#        'P008', 'P097', 'P088', 'P008', 'P097', 'P046', 'P079', 'P029',
#        'P031', 'P090', 'P086', 'P010', 'P029', 'P009', 'P054', 'P052',
# ...

# %%
str(pd.DataFrame(prd_file).product_id)
# Out:
# '0     P001\n1     P002\n2     P003\n3     P004\n4     P005\n      ... \n95    P096\n96    P097\n97    P098\n98    P099\n99    P100\nName: product_id, Length: 100, dtype: object'

# %%
ord22.isin(["\n"])
# Out:
#      order_id  customer_id  product_id  quantity  order_date
# 0       False        False       False     False       False
# 1       False        False       False     False       False
# 2       False        False       False     False       False
# 3       False        False       False     False       False
# 4       False        False       False     False       False
# ..        ...          ...         ...       ...         ...
# 823     False        False       False     False       False
# 824     False        False       False     False       False
# 825     False        False       False     False       False
# 826     False        False       False     False       False
# 827     False        False       False     False       False
#
# [828 rows x 5 columns]

# %%
ord_file
# Out:
#      order_id customer_id product_id  quantity order_date
# 0      O00001       C0333       P022         1 2022-01-09
# 1      O00002       C0068       P090         1 2022-01-27
# 2      O00003       C0483       P021         1 2022-01-17
# 3      O00004       C0214       P076         4 2022-01-07
# 4      O00005       C0411       P073         4 2022-01-12
# ...       ...         ...        ...       ...        ...
# 2579   O02580       C0237       P098         5 2024-12-22
# 2580   O02581       C0236       P007         1 2024-12-05
# 2581   O02582       C0029       P035         1 2024-12-12
# 2582   O02583       C0171       P077         1 2024-12-16
# 2583   O02584       C0421       P038         5 2024-12-01
#
# [2584 rows x 5 columns]

# %%
import os
lis = []
for i in list(os.listdir(path = '.')):
    if i.split('.')[-1] == "ipynb":
        lis.append(i)
print(lis)
lis = [i for i in list(os.listdir(path = '.')) if i.split('.')[-1] == "ipynb"]
# Out:
# ['Assignment7.ipynb', 'Untitled.ipynb']

# %%
pd.DataFrame(prd_file).iloc
