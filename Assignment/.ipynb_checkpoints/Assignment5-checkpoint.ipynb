# %% [markdown]
# # Write a python program that print your name 10 times

# %% [markdown]
# # Write a program to caluclate sum of the even numbers 1 to 20

# %% [markdown]
# # Create a List of Five Fruits
#     * Add a new fruit in list
#     * Remove one fruit from the list
#     * Sort the List in alphabetical order

# %% [markdown]
# # Create a list of squares of numbers from 1 to 10 using list comprehension

# %% [markdown]
# # Create a List Example : ["Alice",'Bob','Alice','Bob','Aly','John'] remove Duplicate from a list

# %% [markdown]
# # Create a Order_Dict Dictionary than store names and marks of students ask the user to 5 students names and marks store in to Dictionary  and print Dictionary

# %% [markdown]
# # Write a python program that takes student dictionary (each containing name , age , and score in three subjects).
#     * Calculate the average score for each student
#     * Find the student with the highest score

# %% [markdown]
# # Write a program that takes a word from the user and print each letter three times using a loop example
#
#     input : cat
#     output : cccaaattt

# %% [markdown]
# # Write a python program that prints 1 to 10 , but skips multiples of 3

# %% [markdown]
# # Given the list of letters ['b','c','a','e','d','o'] write a program to print first vowel

# %% [markdown]
# # Given the list [10,20,30,40,50] remove every second elements and print new list

# %% [markdown]
# # Create a List of images
# example
# ['banana.jpg','apple.png','carrot.jpg','cat.png','honey.png','potato.jpeg']
#
# how many jpg or png or jpeg files in given list

# %% [markdown]
# # Find the longest word in the list example ['apple','banana','cherry','blueberry'] find and print the longest word

# %% [markdown]
# # create a program python program input a user has given text and anlayze them

# %% [markdown]
# # Create a dictionary to store the following student details:
#
#     * Name, Age, Grade, and Subjects (list of subjects).
#
#     * Add a new key-value pair for "School".
#
#     * Update the "Grade" value.
#
#     * Remove the "Age" key.
#
# Print the dictionary after each operation.

# %% [markdown]
# # Write a Python program to count the frequency of each element in a list and store the results in a dictionary.
#
# Example:
#
# Input: [1, 2, 2, 3, 3, 3, 4]
#
# Output: {1: 1, 2: 2, 3: 3, 4: 1}

# %% [markdown]
# # Use list comprehension to filter out all even numbers from a given list.

# %% [markdown]
# # Create a dictionary where the keys are numbers from 1 to 5, and the values are their squares using dictionary comprehension.
