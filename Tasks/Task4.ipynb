# %% [markdown]
# One-sample Z-test
# Scenario: A factory claims that its light bulbs last 1000 hours on average. You test a sample of 50 bulbs and find the sample mean is 980 hours, with a known population standard deviation of 50 hours.
# Question: Is there enough evidence to say the bulbs last less than 1000 hours at a 5% significance level?

# %%
import numpy as np


mu_0 = 1000      
x_bar = 980      
sigma = 50        
n = 50           
alpha = 0.05      


z = (x_bar - mu_0) / (sigma / np.sqrt(n))
print("Z-statistic:", z)


z_critical = -1.645
print("Critical Z-value:", z_critical)


if z < z_critical:
    print("Reject the null hypothesis: Bulbs last less than 1000 hours.")
else:
    print("Fail to reject the null hypothesis: Not enough evidence.")
# Out:
# Z-statistic: -2.8284271247461903
# Critical Z-value: -1.645
# Reject the null hypothesis: Bulbs last less than 1000 hours.
