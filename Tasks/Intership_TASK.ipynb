# %%
import numpy as np
words = ['Ali' , 'Ahmed' , 'Haris' , 'Sami' , 'Osama']
gues = np.random.choice(words)
print(gues)
life = 0

interface = f'{len(gues)*'-'}'
while life != 6:
    print('🎮-Hangman Game Started-🕹')
    life += 1
    print(f'Word = {interface}')
    print(f'Life = {life}/6')
    user_input = input('Guess Word.')
    if user_input in gues:
        for user_input in gues:
            loc = gues.find(user_input)
            gues.replace(user_input , '')
            interface.replace(user_input , '')
# Out:
# Ali
# 🎮-Hangman Game Started-🕹
# Word = ---
# Life = 1/6
# Guess Word. 1
# 🎮-Hangman Game Started-🕹
# Word = ---
# Life = 2/6

# %%
'abcbd'.find('v')
# Out:
# -1

# %%
"jlasjldjla 3 M v".center
# Out:
#   Cell In[7], line 1
#     "jlasjldjla 3 Mv".center)
#                             ^
# SyntaxError: unmatched ')'

# %%
'oooo'.replace('o' , 'e' , 2 )
# Out:
# 'eeoo'

# %%
'dede'.replace
# Out:
# <function str.replace(old, new, /, count=-1)>
